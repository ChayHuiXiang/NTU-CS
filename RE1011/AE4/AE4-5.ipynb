# %% [markdown]
# # Big Poincare section
#
# Because of the periodic nature of the oscillations for $\gamma=0.2,0.28,0.37,0.65$ we only see a few red points, although we are using 100 different values of $t$ to plot the red points.  For example, with $\gamma=0.37$, the oscillation is periodic with period $5T$ and since the red points represent multiples of $T$, we only see five distinct points (all the others overlap these five).
#
# By contrast, for the case $\gamma=0.5$, since the oscillation is non periodic, there are 100 distinct points.
#
# Let's take a look at this case again:

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

def F(t,Y) :
    dydt = Y[1]
    dvdt = -0.3*Y[1]+Y[0]-Y[0]**3+gamma*np.cos(1.2*t)
    return (dydt,dvdt)


T = 2*np.pi/1.2

t = np.linspace(100*T,200*T,5000)
t_poincare = np.arange(100*T,200*T,T)

gamma = 0.5
ysol_d = solve_ivp(F,[0,200*T],[1,0],t_eval=t,max_step=0.1)
ysol_d_poincare = solve_ivp(F,[0,200*T],[1,0],t_eval=t_poincare,max_step=0.1)

plt.plot(ysol_d.y[0],ysol_d.y[1])
plt.plot(ysol_d_poincare.y[0],ysol_d_poincare.y[1],'ro')
plt.title(r'$\gamma$=0.5')

plt.show()

# %% [markdown]
# Looking closer though, they don't seem to be randomly spread, but rather grouped together in clusters. Is this a coincidence or is there a pattern? Let's see what happens if we do this for a much larger number of points!
#
# ## Last Exercise
#
# Plot a new Poincare section, but *only* for the case $\gamma=0.5$ for our initial value problem (with initial conditions $y(0)=1$, $y'(0)=0$). *Do not* create any phase plot, just the Poincare section, but our new Poincare section should contain many more points than we did above:
#
# Tell `solve_ivp` to solve the i.v.p. on the interval $[0,50000T]$ but only plot points for values of $t$, starting at $t=100T$, with an equal distance $T$ apart (so you're only looking at multiples of $T$), and lying in the interval $[100T,50000T])$. You can do this by passing a suitable array as the `t_eval` argument, where the array can be easily constructed using the `np.arange()` function.
#
# In case you forgot, `np.arange()` function works like `np.linspace()` but instead of specifying the number of points to return, it asks instead for the space between the points.
#
# More precisely, `np.arange(a,b,h)` returns a Numpy array of increasing values in the interval $[a,b)$ spaced a distance `h` apart and starting with `a`.
#
# ## What to do
# Complete the code below (only one small detail is missing) which generates the Poincare section. This is your last exercise for this AE. Note that since we're solving the i.v.p. on such a long interval, the calculations for solving will take quite long to perform. On my computer it took about 5 minutes. You might want to try first on a much shorter interval just to check that your code seems to work.
#
# ## To submit in LAMS
# Submit your final plot of the Poincare section as the answer to this exercise.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

def F(t,Y) :
    dydt = Y[1]
    dvdt = -0.3*Y[1]+Y[0]-Y[0]**3+gamma*np.cos(1.2*t)
    return (dydt,dvdt)

gamma = 0.5

T=2*np.pi/1.2

# Create a suitable array t for us to use as t_eval below.
# We want to plot the calculated solution values for values of t starting at 100T,
# equally spaced a distance T from each other and all in the interval [100T,50000T)
# The function np.arange() is useful here.

# Complete the row below.
t = np.arange(100*T,50000*T,T)

ysol = solve_ivp(F,[0,50000*T],[1,0],t_eval=t,max_step=0.1)

plt.clf()

plt.plot(ysol.y[0],ysol.y[1],'.',markersize=1)

plt.show()

# %% [markdown]
# In case the plot does not open in a separate window, instead of re-running the entire cell and waiting ten more minutes, just run the plot commands below again.

# %%
# %matplotlib qt
plt.clf()
plt.plot(ysol.y[0],ysol.y[1],'.',markersize=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\CHAYHU~1\AppData\Local\Temp/ipykernel_20984/1594176727.py in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 plt.clf()
#       3 plt.plot(ysol.y[0],ysol.y[1],'.',markersize=1)
#       4 plt.show()
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    3528                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3529
# -> 3530         pt.activate_matplotlib(backend)
#    3531         configure_inline_support(self, backend)
#    3532
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py in activate_matplotlib(backend)
#     322     from matplotlib import pyplot as plt
#     323
# --> 324     plt.switch_backend(backend)
#     325
#     326     plt.show._needmain = False
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in switch_backend(newbackend)
#     274     backend_name = cbook._backend_module_name(newbackend)
#     275
# --> 276     class backend_mod(matplotlib.backend_bases._Backend):
#     277         locals().update(vars(importlib.import_module(backend_name)))
#     278
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in backend_mod()
#     275
#     276     class backend_mod(matplotlib.backend_bases._Backend):
# --> 277         locals().update(vars(importlib.import_module(backend_name)))
#     278
#     279     required_framework = _get_required_interactive_framework(backend_mod)
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_qt5agg.py in <module>
#       9 from .. import cbook
#      10 from .backend_agg import FigureCanvasAgg
# ---> 11 from .backend_qt5 import (
#      12     QtCore, QtGui, QtWidgets, _BackendQT5, FigureCanvasQT, FigureManagerQT,
#      13     NavigationToolbar2QT, backend_version)
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_qt5.py in <module>
#      14     _Backend, FigureCanvasBase, FigureManagerBase, NavigationToolbar2,
#      15     TimerBase, cursors, ToolContainerBase, StatusbarBase, MouseButton)
# ---> 16 import matplotlib.backends.qt_editor.figureoptions as figureoptions
#      17 from matplotlib.backends.qt_editor._formsubplottool import UiSubplotTool
#      18 from . import qt_compat
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\qt_editor\figureoptions.py in <module>
#       9
#      10 from matplotlib import cbook, cm, colors as mcolors, markers, image as mimage
# ---> 11 from matplotlib.backends.qt_compat import QtGui
#      12 from matplotlib.backends.qt_editor import _formlayout
#      13
#
# c:\users\chay hui xiang\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\qt_compat.py in <module>
#     175         break
#     176     else:
# --> 177         raise ImportError("Failed to import any qt binding")
#     178 else:  # We should not get there.
#     179     raise AssertionError("Unexpected QT_API: {}".format(QT_API))
#
# ImportError: Failed to import any qt binding
